# %%
# !pip install dcm2niix
# Out:
# WARNING: Ignoring invalid distribution -ydicom (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ydicom (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# Requirement already satisfied: dcm2niix in ./anaconda3/lib/python3.6/site-packages (1.0.20220715)
# Requirement already satisfied: miutil[web] in ./anaconda3/lib/python3.6/site-packages (from dcm2niix) (0.10.1)
# Requirement already satisfied: tqdm>=4.40.0 in ./anaconda3/lib/python3.6/site-packages (from miutil[web]->dcm2niix) (4.61.0)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.6/site-packages (from miutil[web]->dcm2niix) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./anaconda3/lib/python3.6/site-packages (from requests->miutil[web]->dcm2niix) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.6/site-packages (from requests->miutil[web]->dcm2niix) (2018.11.29)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.6/site-packages (from requests->miutil[web]->dcm2niix) (2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.6/site-packages (from requests->miutil[web]->dcm2niix) (1.22)
# WARNING: Ignoring invalid distribution -ydicom (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ydicom (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ydicom (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Users/gengshuang/anaconda3/lib/python3.6/site-packages)

# %%
import dcm2niix


source_dir = '/Volumes/shuang/depression/HC/HC_dd'
target_dir = '/Volumes/shuang/depression/HC_nii'

# %%
# %cd /Volumes/shuang/depression
# Out:
# /Volumes/shuang

# %%
import subprocess
import os

def convert_dicom_to_nifti(input_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    try:
        # Run the dcm2niix command
        result = subprocess.run(
            ['dcm2niix', '','y', '-z', 'y','-o', output_dir, '-f', filename_format, input_dir],
            check=True,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            universal_newlines=True
        )
        
        # Print the output
        print("Standard Output:")
        print(result.stdout)
        
        if result.stderr:
            print("Standard Error:")
            print(result.stderr)
        
        print("Conversion completed successfully.")
        return True
    
    except subprocess.CalledProcessError as e:
        print(f"An error occurred during conversion: {e}")
        print(f"Command output: {e.output}")
        return False

# Usage
subject_dir = source_dir
target_dir = target_dir

for subfoler_name in os.listdir(subject_dir):
    subject_dir_path = os.path.join(subject_dir, subfoler_name)
    if os.path.isdir(subject_dir_path):
        input_directory = [f.path for f in os.scandir(subject_dir_path) if f.is_dir() and 't1' in f.name]
        if input_directory:  # Check if the list is not empty
            input_directory = input_directory[0]  # Take the first matching directory
            output_directory = os.path.join(target_dir, subfoler_name,'anat')
            filename_format = f'sub-{subfoler_name}_T1w'
            success = convert_dicom_to_nifti(input_directory, output_directory)
            if success:
                print(f"Conversion was successful for {subfoler_name}.")
            else:
                print(f"Conversion failed for {subfoler_name}.")
        else:
            print(f"No 'diff' directory found in {subfoler_name}.")
# Out:
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/003/anat/sub-003_T1w (256x256x192x1)
# Conversion required 1.751471 seconds (1.457113 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 003.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/004/anat/sub-004_T1w (256x256x192x1)
# Conversion required 1.674833 seconds (1.424702 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 004.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/005/anat/sub-005_T1w (256x256x192x1)
# Conversion required 1.635325 seconds (1.412143 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 005.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/006/anat/sub-006_T1w (256x256x192x1)
# Conversion required 1.703501 seconds (1.410004 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 006.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/007/anat/sub-007_T1w (256x256x192x1)
# Conversion required 1.643386 seconds (1.385374 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 007.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/008/anat/sub-008_T1w (256x256x192x1)
# Conversion required 1.669814 seconds (1.367405 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 008.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/009/anat/sub-009_T1w (256x256x192x1)
# Conversion required 1.666188 seconds (1.385891 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 009.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/010/anat/sub-010_T1w (256x256x192x1)
# Conversion required 1.738030 seconds (1.444068 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 010.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/011/anat/sub-011_T1w (256x256x192x1)
# Conversion required 1.694603 seconds (1.416117 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 011.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/012/anat/sub-012_T1w (256x256x192x1)
# Conversion required 1.635413 seconds (1.369481 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 012.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/013/anat/sub-013_T1w (256x256x192x1)
# Conversion required 1.760380 seconds (1.472830 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 013.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/014/anat/sub-014_T1w (256x256x192x1)
# Conversion required 1.642885 seconds (1.384185 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 014.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/015/anat/sub-015_T1w (256x256x192x1)
# Conversion required 1.786467 seconds (1.508232 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 015.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/017/anat/sub-017_T1w (256x256x192x1)
# Conversion required 1.682801 seconds (1.406805 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 017.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/019/anat/sub-019_T1w (256x256x192x1)
# Conversion required 1.842438 seconds (1.442355 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 019.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/020/anat/sub-020_T1w (256x256x192x1)
# Conversion required 1.910719 seconds (1.554163 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 020.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/021/anat/sub-021_T1w (256x256x192x1)
# Conversion required 1.708726 seconds (1.423317 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 021.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/022/anat/sub-022_T1w (256x256x192x1)
# Conversion required 1.805618 seconds (1.422566 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 022.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/023/anat/sub-023_T1w (256x256x192x1)
# Conversion required 1.865641 seconds (1.474113 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 023.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/026/anat/sub-026_T1w (256x256x192x1)
# Conversion required 1.647435 seconds (1.378659 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 026.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/027/anat/sub-027_T1w (256x256x192x1)
# Conversion required 1.724990 seconds (1.451659 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 027.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/028/anat/sub-028_T1w (256x256x192x1)
# Conversion required 1.719947 seconds (1.406928 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 028.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/030/anat/sub-030_T1w (256x256x192x1)
# Conversion required 1.683991 seconds (1.412268 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 030.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/031/anat/sub-031_T1w (256x256x192x1)
# Conversion required 1.644174 seconds (1.364658 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 031.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/032/anat/sub-032_T1w (256x256x192x1)
# Conversion required 1.678719 seconds (1.377062 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 032.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/033/anat/sub-033_T1w (256x256x192x1)
# Conversion required 2.623065 seconds (1.543288 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 033.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/034/anat/sub-034_T1w (256x256x192x1)
# Conversion required 1.706719 seconds (1.421850 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 034.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/043/anat/sub-043_T1w (256x256x192x1)
# Conversion required 1.765555 seconds (1.504571 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 043.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/044/anat/sub-044_T1w (256x256x192x1)
# Conversion required 1.650186 seconds (1.412608 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 044.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/304/anat/sub-304_T1w (256x256x192x1)
# Conversion required 1.685968 seconds (1.408600 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 304.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/309/anat/sub-309_T1w (256x256x192x1)
# Conversion required 1.564441 seconds (1.299045 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 309.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/310/anat/sub-310_T1w (256x256x192x1)
# Conversion required 1.696515 seconds (1.415550 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 310.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/311/anat/sub-311_T1w (256x256x192x1)
# Conversion required 1.669553 seconds (1.394123 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 311.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/314/anat/sub-314_T1w (256x256x192x1)
# Conversion required 1.736517 seconds (1.429941 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 314.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/317/anat/sub-317_T1w (256x256x192x1)
# Conversion required 1.752005 seconds (1.430286 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 317.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/321/anat/sub-321_T1w (256x256x192x1)
# Conversion required 1.754857 seconds (1.439035 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 321.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/322/anat/sub-322_T1w (256x256x192x1)
# Conversion required 1.801870 seconds (1.486575 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 322.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/323/anat/sub-323_T1w (256x256x192x1)
# Conversion required 1.667785 seconds (1.372088 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 323.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/324/anat/sub-324_T1w (256x256x192x1)
# Conversion required 1.697103 seconds (1.360269 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 324.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/326/anat/sub-326_T1w (256x256x192x1)
# Conversion required 2.024464 seconds (1.510153 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 326.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/331/anat/sub-331_T1w (256x256x192x1)
# Conversion required 1.950951 seconds (1.557309 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 331.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/336/anat/sub-336_T1w (256x256x192x1)
# Conversion required 1.702453 seconds (1.438353 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 336.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/337/anat/sub-337_T1w (256x256x192x1)
# Conversion required 1.623468 seconds (1.372295 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 337.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/342/anat/sub-342_T1w (256x256x192x1)
# Conversion required 1.692847 seconds (1.429509 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 342.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/343/anat/sub-343_T1w (256x256x192x1)
# Conversion required 1.685756 seconds (1.379321 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 343.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/345/anat/sub-345_T1w (256x256x192x1)
# Conversion required 1.676683 seconds (1.417152 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 345.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/346/anat/sub-346_T1w (256x256x192x1)
# Conversion required 1.673296 seconds (1.340464 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 346.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/364/anat/sub-364_T1w (256x256x192x1)
# Conversion required 1.740408 seconds (1.439839 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 364.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/365/anat/sub-365_T1w (256x256x192x1)
# Conversion required 1.890340 seconds (1.393873 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 365.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/367/anat/sub-367_T1w (256x256x192x1)
# Conversion required 1.551036 seconds (1.320106 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 367.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/368/anat/sub-368_T1w (256x256x192x1)
# Conversion required 1.675620 seconds (1.428210 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 368.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/372/anat/sub-372_T1w (256x256x192x1)
# Conversion required 1.939060 seconds (1.476323 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 372.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/381/anat/sub-381_T1w (256x256x192x1)
# Conversion required 1.698978 seconds (1.434235 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 381.
# Standard Output:
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang10.0.1 x86-64 (64-bit MacOS)
# Found 192 DICOM file(s)
# Convert 192 DICOM as /Volumes/shuang/depression/HC_nii/402/anat/sub-402_T1w (256x256x192x1)
# Conversion required 1.799281 seconds (1.442631 for core code).
#
# Conversion completed successfully.
# Conversion was successful for 402.

# %%
output_directory = os.path.join(target_dir, subfoler_name,'resting')

# %%
target_dir
# Out:
# '/Volumes/shuang/depression/HC_nii'

# %%
output_directory
# Out:
# '/Volumes/shuang/depression/HC_nii/resting/003'
