# %%
import os
import subprocess

# Set up FSL environment
fsl_path = "/home/a1/fsl"
os.environ["FSLDIR"] = fsl_path
os.environ["PATH"] += os.pathsep + os.path.join(fsl_path, "bin")
os.environ["FSLOUTPUTTYPE"] = "NIFTI_GZ"

# Define base directory where the BIDS data is stored
BASE_DIR = "/home/a1/Desktop/Projects/forkx/HC_nii"
FREE_DIR = "/home/a1/Desktop/Projects/forkx/HC_nii"
# Path to the list of subjects file
SUBJECT_LIST = "/home/a1/Desktop/Projects/code/hc_list.txt"

# Read the list of subjects
with open(SUBJECT_LIST, 'r') as file:
    subjects = file.read().splitlines()

# Loop over each subject in the list
for SUBJ in subjects:
    SUBJ_ID = f"sub-{SUBJ}"
    print(f"Processing {SUBJ_ID}")

    # Define subject directory
    SUBJ_DIR = os.path.join(BASE_DIR, SUBJ_ID)

    # Define file paths
    t1_fname = os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_brainmask_in_space.nii.gz")
    label_fname = os.path.join(FREE_DIR, f"{SUBJ}","mri", "wm_bin.nii.gz")
    MAT = os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_brainmask_to_dwi.mat")
    BVAL = os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_dwi.bval")
    BVEC = os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_dwi.bvec")
    WM = os.path.join(FREE_DIR, f"{SUBJ}","mri", "wm_in_dwi.nii.gz")
    EDDY_IMAGE = os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_dwi_brain.nii.gz")
    OUT=os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_b0_brain_in_MNI.nii.gz")
    WM_bin = os.path.join(FREE_DIR, f"{SUBJ}","mri", "wm_bin.nii.gz")
    WM_MIF = os.path.join(FREE_DIR, f"{SUBJ}","mri", "wm.mif")
    B0=os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_b0.nii.gz")
    mean_B0=os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_b0_mean.nii.gz")
    brain=os.path.join(FREE_DIR, f"{SUBJ}","mri", "brain.mgz")
    brainnii=os.path.join(FREE_DIR, f"{SUBJ}","mri", "brain.nii.gz")

    eddy_OUTPUT=os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_dwi_in_MNI.nii.gz")
    B0_in_MNI=os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_b0_brain_in_MNI.nii.gz1Warp.nii.gz") 
    TransMAT=os.path.join(SUBJ_DIR, 'dwi', f"{SUBJ_ID}_b0_brain_in_MNI.nii.gz0GenericAffine.mat") 
    MRTIX3_DWI = os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}_dwi.mif") 
    fOD = os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}_fod.mif") 
    reponsetxt=os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}_response_wm.txt") 
    reponsetxt1=os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}_response_gm.txt") 
    reponsetxt2=os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}_response_csf.txt") 
    streamlines=os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}_tck2MNI.tck") 

    atlas='/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz'

    flix=os.path.join(SUBJ_DIR, 'streamline', f"{SUBJ_ID}")
    #00#
    convert_cmd = ['tck2connectome', streamlines, atlas, f"{flix}-connectome.csv",'-out_assignments', f"{flix}-assignments.csv", 
                   '-zero_diagonal', '-symmetric', '-force']
    try:
        subprocess.run(convert_cmd, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error running BET: {e}")
        continue
    

    connectome = np.loadtxt(f"{flix}-connectome.csv", delimiter=",")
    sns.heatmap(connectome, square=True, cmap="viridis")
    plt.title("connectivity matrix")
    plt.show
# Out:
# Processing sub-004
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-005
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-006
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-007
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-009
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-017
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-019
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-020
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-021
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-022
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-026
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-027
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-028
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-030
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-031
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-032
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-033
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-034
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-043
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-304
# Error running BET: Command '['tck2connectome', '/home/a1/Desktop/Projects/forkx/HC_nii/sub-304/streamline/sub-304_tck2MNI.tck', '/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz', '/home/a1/Desktop/Projects/forkx/HC_nii/sub-304/streamline/sub-304-connectome.csv', '-out_assignments', '/home/a1/Desktop/Projects/forkx/HC_nii/sub-304/streamline/sub-304-assignments.csv', '-zero_diagonal', '-symmetric', '-force']' returned non-zero exit status 1.
# Processing sub-309
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: [ERROR] required input file "/home/a1/Desktop/Projects/forkx/HC_nii/sub-304/streamline/sub-304_tck2MNI.tck" not found
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-310
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-311
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-314
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-317
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-321
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-322
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-323
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-324
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-326
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-336
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-343
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-345
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-346
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-364
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-365
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-367
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-368
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-372
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-381
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K
# Processing sub-402
# tck2connectome: [WARNING] existing output files will be overwritten
# tck2connectome: Image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz" stored with floating-point type; need to check for non-integer or negative values
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Verifying parcellation image[0K
# tck2connectome: [100%] uncompressing image "/home/a1/Desktop/Projects/template/gordon333MNI.nii.gz"[0K
# tck2connectome: [100%] Constructing connectome[0K

# %%
    connectome = np.loadtxt(f"{flix}-connectome.csv", delimiter=",")
    sns.heatmap(connectome, square=True, cmap="viridis")
    plt.title("connectivity matrix")
    plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import binary_dilation

from dipy.core.gradients import gradient_table
from dipy.data import get_fnames
from dipy.io.gradients import read_bvals_bvecs
from dipy.io.image import load_nifti_data, load_nifti, save_nifti
from dipy.io.stateful_tractogram import Space, StatefulTractogram
from dipy.io.streamline import save_trk
from dipy.direction import peaks
from dipy.reconst import shm
from dipy.tracking import utils
from dipy.tracking.local_tracking import LocalTracking
from dipy.tracking.stopping_criterion import BinaryStoppingCriterion
from dipy.tracking.streamline import Streamlines
from dipy.viz import window, actor, colormap as cmap
from os.path import join as pjoin

from dipy.align import affine_registration, syn_registration
from dipy.align.reslice import reslice
from dipy.core.gradients import gradient_table
from dipy.data import get_fnames, fetch_stanford_tracks
from dipy.data.fetcher import (fetch_mni_template, read_mni_template)
from dipy.io.gradients import read_bvals_bvecs
from dipy.io.image import load_nifti
from dipy.io.stateful_tractogram import Space, StatefulTractogram
from dipy.io.streamline import save_tractogram, load_tractogram
from dipy.segment.mask import median_otsu
from dipy.tracking.streamline import transform_streamlines
from dipy.viz import regtools, has_fury, horizon
import os

import nibabel as nib
from dipy.io.stateful_tractogram import Space, StatefulTractogram
from dipy.io.streamline import load_tractogram, save_tractogram
from dipy.io.utils import (create_nifti_header, get_reference_info,
                           is_header_compatible)
from dipy.tracking.streamline import select_random_set_of_streamlines
from dipy.tracking.utils import density_map

from dipy.data.fetcher import (fetch_file_formats,
                               get_file_formats)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
5, 9, 61, 87, 92, 93, 94, 95, 97, 98, 99, 132, 137, 139, 140, 141, 166, 170, 252, 253, 255, 256, 257, 258, 259, 263, 264, 266, 303, 307, 309, 310
